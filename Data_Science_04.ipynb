# %% [markdown]
# <a href="https://colab.research.google.com/github/SandhuruT/Data_Science_01/blob/main/Data_Science_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

messy_dt = pd.read_csv('/content/messy_sales.csv')
messy_dt.head()
# Out:
#    order_id customer_name    age       city product_category  quantity  \
# 0      1001     Raj Kumar   28.0     Mumbai      Electronics         2
# 1      1002  Priya Sharma    NaN      Delhi         Clothing         1
# 2      1003    Amit Singh   35.0  Bangalore      Electronics         3
# 3      1004     Raj Kumar   28.0     Mumbai      Electronics         2
# 4      1005   Sneha Patel  999.0    Chennai            Books         2
#
#    unit_price  discount payment_method  order_date  delivery_days  rating  \
# 0        1500      10.0            UPI  2023-01-05            3.0     4.0
# 1         800       NaN    Credit Card  2023-01-07            5.0     3.0
# 2        2000      15.0            UPI  2023-01-10            NaN     5.0
# 3        1500      10.0            UPI  2023-01-05            3.0     4.0
# 4         500       0.0     Debit Card  2023-01-12            4.0     2.0
#
#   returned
# 0       No
# 1       No
# 2       No
# 3       No
# 4      Yes

# %%
messy_dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          50 non-null     int64
#  1   customer_name     49 non-null     object
#  2   age               48 non-null     float64
#  3   city              50 non-null     object
#  4   product_category  50 non-null     object
#  5   quantity          50 non-null     int64
#  6   unit_price        50 non-null     int64
#  7   discount          48 non-null     float64
#  8   payment_method    50 non-null     object
#  9   order_date        50 non-null     object
#  10  delivery_days     46 non-null     float64
#  11  rating            48 non-null     float64
#  12  returned          50 non-null     object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 5.2+ KB

# %%
messy_dt.isnull().sum()
# Out:
# order_id            0
# customer_name       1
# age                 2
# city                0
# product_category    0
# quantity            0
# unit_price          0
# discount            2
# payment_method      0
# order_date          0
# delivery_days       4
# rating              2
# returned            0
# dtype: int64

# %%
messy_dt.dtypes
# Out:
# order_id              int64
# customer_name        object
# age                 float64
# city                 object
# product_category     object
# quantity              int64
# unit_price            int64
# discount            float64
# payment_method       object
# order_date           object
# delivery_days       float64
# rating              float64
# returned             object
# dtype: object

# %%
messy_dt.describe()
# Out:
#          order_id         age   quantity    unit_price   discount  \
# count    50.00000   48.000000  50.000000     50.000000  48.000000
# mean   1025.50000   53.375000   1.760000   2938.160000   6.354167
# std      14.57738  139.737691   0.959592   4080.020515   5.901639
# min    1001.00000   -5.000000   0.000000    499.000000   0.000000
# 25%    1013.25000   28.000000   1.000000    750.000000   0.000000
# 50%    1025.50000   32.500000   1.500000   1050.000000   7.500000
# 75%    1037.75000   39.000000   2.000000   2200.000000  10.000000
# max    1050.00000  999.000000   4.000000  15999.000000  20.000000
#
#        delivery_days     rating
# count      46.000000  48.000000
# mean        4.195652   3.833333
# std         1.654886   0.833688
# min         2.000000   2.000000
# 25%         3.000000   3.000000
# 50%         4.000000   4.000000
# 75%         5.000000   4.000000
# max         8.000000   5.000000

# %%
messy_dt.duplicated().sum()
# Out:
# np.int64(0)

# %%
messy_dt[messy_dt.duplicated(keep=False)].sort_values('order_id')
# Out:
# Empty DataFrame
# Columns: [order_id, customer_name, age, city, product_category, quantity, unit_price, discount, payment_method, order_date, delivery_days, rating, returned]
# Index: []

# %%
messy_dt["order_id"].value_counts()
# Out:
# order_id
# 1001    1
# 1002    1
# 1003    1
# 1004    1
# 1005    1
# 1006    1
# 1007    1
# 1008    1
# 1009    1
# 1010    1
# 1011    1
# 1012    1
# 1013    1
# 1014    1
# 1015    1
# 1016    1
# 1017    1
# 1018    1
# 1019    1
# 1020    1
# 1021    1
# 1022    1
# 1023    1
# 1024    1
# 1025    1
# 1026    1
# 1027    1
# 1028    1
# 1029    1
# 1030    1
# 1031    1
# 1032    1
# 1033    1
# 1034    1
# 1035    1
# 1036    1
# 1037    1
# 1038    1
# 1039    1
# 1040    1
# 1041    1
# 1042    1
# 1043    1
# 1044    1
# 1045    1
# 1046    1
# 1047    1
# 1048    1
# 1049    1
# 1050    1
# Name: count, dtype: int64

# %%
messy_dt.head()
# Out:
#    order_id customer_name    age       city product_category  quantity  \
# 0      1001     Raj Kumar   28.0     Mumbai      Electronics         2
# 1      1002  Priya Sharma    NaN      Delhi         Clothing         1
# 2      1003    Amit Singh   35.0  Bangalore      Electronics         3
# 3      1004     Raj Kumar   28.0     Mumbai      Electronics         2
# 4      1005   Sneha Patel  999.0    Chennai            Books         2
#
#    unit_price  discount payment_method  order_date  delivery_days  rating  \
# 0        1500      10.0            UPI  2023-01-05            3.0     4.0
# 1         800       NaN    Credit Card  2023-01-07            5.0     3.0
# 2        2000      15.0            UPI  2023-01-10            NaN     5.0
# 3        1500      10.0            UPI  2023-01-05            3.0     4.0
# 4         500       0.0     Debit Card  2023-01-12            4.0     2.0
#
#   returned
# 0       No
# 1       No
# 2       No
# 3       No
# 4      Yes

# %%
columns = ["customer_name","city","product_category","quantity","unit_price","order_date"]

messy_dt.duplicated(subset = columns).sum()
# Out:
# np.int64(5)

# %%
messy_dt[messy_dt.duplicated(subset = columns,keep=False)].value_counts("customer_name")
# Out:
# customer_name
# Raj Kumar       4
# Priya Sharma    2
# Sneha Patel     2
# Name: count, dtype: int64

# %%
messy_dt["age"].describe()
# Out:
# count     48.000000
# mean      53.375000
# std      139.737691
# min       -5.000000
# 25%       28.000000
# 50%       32.500000
# 75%       39.000000
# max      999.000000
# Name: age, dtype: float64

# %%
messy_dt[messy_dt["age"]<=0]
# Out:
#     order_id customer_name  age     city product_category  quantity  \
# 19      1020   Sneha Patel -5.0  Chennai            Books         2
#
#     unit_price  discount payment_method  order_date  delivery_days  rating  \
# 19         500       0.0     Debit Card  2023-01-12            4.0     2.0
#
#    returned
# 19      Yes

# %%
messy_dt[messy_dt["age"]>100]
# Out:
#    order_id customer_name    age     city product_category  quantity  \
# 4      1005   Sneha Patel  999.0  Chennai            Books         2
#
#    unit_price  discount payment_method  order_date  delivery_days  rating  \
# 4         500       0.0     Debit Card  2023-01-12            4.0     2.0
#
#   returned
# 4      Yes

# %%
messy_dt[messy_dt["quantity"]<=0]
# Out:
#     order_id customer_name   age       city product_category  quantity  \
# 21      1022    Amit Singh  35.0  Bangalore      Electronics         0
#
#     unit_price  discount payment_method  order_date  delivery_days  rating  \
# 21        2000      15.0            UPI  2023-02-25            NaN     5.0
#
#    returned
# 21       No

# %%
# drop missing value
messy_dt = messy_dt.dropna(subset=["customer_name"])

# %%
messy_dt["age"] = messy_dt["age"].fillna(messy_dt["age"].median())

# %%
messy_dt["discount"] = messy_dt["discount"].fillna(0)

# %%
messy_dt["delivery_days"] = messy_dt["delivery_days"].fillna(messy_dt["age"].median())

# %%
messy_dt["rating"] = messy_dt["rating"].fillna(messy_dt["rating"].median())

# %%
messy_dt.isnull().sum()
# Out:
# order_id            0
# customer_name       0
# age                 0
# city                0
# product_category    0
# quantity            0
# unit_price          0
# discount            0
# payment_method      0
# order_date          0
# delivery_days       0
# rating              0
# returned            0
# dtype: int64

# %%
messy_dt.shape
# Out:
# (49, 13)

# %%
# Remove Duplicate transaction
messy_dt = messy_dt.drop_duplicates(subset = columns)

# %%
messy_dt.shape[0]
# Out:
# 44

# %%
columns = ["customer_name","city","product_category","quantity","unit_price","order_date"]

messy_dt.duplicated(subset = columns).sum()
# Out:
# np.int64(0)

# %%
messy_dt[messy_dt.duplicated(subset = columns,keep=False)].value_counts("customer_name")
# Out:
# Series([], Name: count, dtype: int64)

# %%
messy_dt = messy_dt.drop(messy_dt[messy_dt["quantity"]<=0].index)

# %%
messy_dt[messy_dt["quantity"]<=0]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_name, age, city, product_category, quantity, unit_price, discount, payment_method, order_date, delivery_days, rating, returned]
# Index: []

# %%
messy_dt.loc[messy_dt["age"]<=0, "age"] = messy_dt["age"].median()

# %%
messy_dt[messy_dt["age"]<=0]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_name, age, city, product_category, quantity, unit_price, discount, payment_method, order_date, delivery_days, rating, returned]
# Index: []

# %%
messy_dt.loc[messy_dt["age"] > 100, "age"] = messy_dt["age"].median()

# %%
messy_dt[messy_dt["age"]>100]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_name, age, city, product_category, quantity, unit_price, discount, payment_method, order_date, delivery_days, rating, returned]
# Index: []

# %%
messy_dt["order_date"] = pd.to_datetime(messy_dt["order_date"])
messy_dt.dtypes
# Out:
# order_id                     int64
# customer_name               object
# age                        float64
# city                        object
# product_category            object
# quantity                     int64
# unit_price                   int64
# discount                   float64
# payment_method              object
# order_date          datetime64[ns]
# delivery_days              float64
# rating                     float64
# returned                    object
# dtype: object

# %%
print (f"total shape:  {messy_dt.shape[0]}")


print(f" duplicate remaining : {messy_dt.duplicated(subset = columns).sum()}")

print(f" zero quantity row: {messy_dt[messy_dt["quantity"]<=0].shape[0]}")

print(f" invalied age : {messy_dt[(messy_dt["age"]<=0) | (messy_dt["age"]>100 )].shape[0]}")

print(f"data dtype: {messy_dt["order_date"].dtype}")

print(f"total null values: {messy_dt.isnull().sum()}")
# Out:
# total shape:  43
#  duplicate remaining : 0
#  zero quantity row: 0
#  invalied age : 0
# data dtype: datetime64[ns]
# total null values: order_id            0
# customer_name       0
# age                 0
# city                0
# product_category    0
# quantity            0
# unit_price          0
# discount            0
# payment_method      0
# order_date          0
# delivery_days       0
# rating              0
# returned            0
# dtype: int64

# %%
print(messy_dt.columns.tolist())
# Out:
# ['order_id', 'customer_name', 'age', 'city', 'product_category', 'quantity', 'unit_price', 'discount', 'payment_method', 'order_date', 'delivery_days', 'rating', 'returned']

# %%
# Add revenue column.
messy_dt["revenue"] = messy_dt["quantity"] * messy_dt["unit_price"] * (1 - messy_dt["discount"] / 100)

# %%
messy_dt[["customer_name","quantity","unit_price","discount","revenue"]].head()
# Out:
#   customer_name  quantity  unit_price  discount  revenue
# 0     Raj Kumar         2        1500      10.0   2700.0
# 1  Priya Sharma         1         800       0.0    800.0
# 2    Amit Singh         3        2000      15.0   5100.0
# 4   Sneha Patel         2         500       0.0   1000.0
# 5   Vikram Iyer         1        1200       5.0   1140.0

# %%
# product category generates most revenue
revenue_by_category = messy_dt.groupby("product_category")["revenue"].sum()
revenue_by_category
# Out:
# product_category
# Beauty            16140.0
# Books              7391.0
# Clothing          14790.0
# Electronics       84894.6
# Home & Kitchen    26015.0
# Name: revenue, dtype: float64

# %%
most_revenue_category = revenue_by_category.idxmax()
max_revenue_amount = revenue_by_category.max()

# %%
print(most_revenue_category)
print(max_revenue_amount)
# Out:
# Electronics
# 84894.6

# %%
#  Average delivery days by city.
delivery_day = messy_dt.groupby("city")["delivery_days"].mean()
delivery_day
# Out:
# city
# Ahmedabad     3.000000
# Bangalore    13.333333
# Bhopal        2.000000
# Chennai       5.200000
# Delhi         5.000000
# Hyderabad     2.000000
# Indore       22.666667
# Jaipur        4.000000
# Kochi         3.000000
# Kolkata       8.000000
# Lucknow       5.000000
# Mumbai        3.500000
# Nagpur        6.000000
# Surat         3.000000
# Name: delivery_days, dtype: float64

# %%
# discount percentage affect rating
plt.scatter(messy_dt["discount"], messy_dt["rating"])
plt.xlabel("discount")
plt.ylabel("rating")
plt.title("discount vs rating")
plt.show()
